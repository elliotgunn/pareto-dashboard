# %%
import pandas as pd
import numpy as np
import glob
import numpy as np

# from plotly.graph_objs import *
# import plotly as px

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/sample.csv', index_col=0)

# %%
df.head()
# Out:
#       product customer_id  amount
# 0  outlxwfhyu   customer1       0
# 1  ukjakcfikb   customer2       0
# 2  fstxfaulvj   customer3      15
# 3  wcpurpgyce   customer4     178
# 4  oyhjphvfbb   customer5     157

# %%
# drop rows with amount=0
# df = df.drop(df[df.amount <= 0].index)

# %%
def pareto_analysis_one(df, col, percentile):
    """
    Returns list object. 
    """
    
    # total # of products for the month
    total_products = len(df.index)
        
    # sort dataframe in desc order by col selected, in this case, just price
    df = df.sort_values(by=col, ascending=False)

    # perc share amount spent. not neccessary for calc but good for ground truth
    total_amount = df[col].sum()
    df['perc_share_amount'] = (df[col] / total_amount)*100
  
    # cumulative percentile
    df['cum_sum_amount'] = df[col].cumsum()
    df['cum_sum_perc_amount'] = 100*df['cum_sum_amount']/total_amount

    # filter the df where cum_sum_perc_amount reach 80.0
    df = df[df['cum_sum_perc_amount'] < percentile]

    # now calculate the KPI
    num_products = len(df.index)
    kpi = (num_products/total_products)*100
    
    return(round(kpi, 2))

# test
pareto_analysis_one(df, 'amount', 80.00)

# 80% of amount spent was generated by 20.45% of unique products
# Out:
# 20.45

# %% [markdown]
# ### Make Plotly pareto chart
# # Code modified from
# link[https://newbedev.com/how-to-overlay-two-plots-in-same-figure-in-plotly-create-pareto-chart-in-plotly]!

# %%
df.describe()
# 1098 entries

df['product'].value_counts() # 1098 unique products
df['customer_id'].value_counts() # 561 unique customers
# Out:
# customer412    18
# customer123     8
# customer23      7
# customer105     7
# customer47      7
#                ..
# customer136     1
# customer111     1
# customer645     1
# customer294     1
# customer684     1
# Name: customer_id, Length: 562, dtype: int64

# %%
df = df.drop(columns='customer_id')

# %%
df = df.sort_values(by=['amount'], ascending=False)
df['cumulative_sum'] = df.amount.cumsum()
df['cumulative_perc'] = 100*df.cumulative_sum/df.amount.sum()
df.head(200)
# Out:
#          product  amount  cumulative_sum  cumulative_perc
# 1192  teptlezwgy  170577          170577         4.111711
# 1325  pweflqandk  147300          317877         7.662336
# 1140  mkbtkziftf  106332          424209        10.225439
# 69    ptctwlpjbg   91496          515705        12.430925
# 820   mwvqtdpxik   84535          600240        14.468617
# ...          ...     ...             ...              ...
# 892   svyeloswfa    4385         3202904        77.205106
# 78    oswtzbraym    4341         3207245        77.309744
# 1313  satiorpbqm    4297         3211542        77.413322
# 644   ejektlxmsr    4212         3215754        77.514852
# 717   rzqmyhwzlv    4156         3219910        77.615031
#
# [200 rows x 4 columns]

# %%
# make two tables:
# the first table: once cumulative_perc hits 80%
# the second table: after cumulative_perc hits 80%
top_80 = df.drop(df[df.cumulative_perc > 80.0].index)
bottom_20 = df.drop(df[df.cumulative_perc <= 80.0].index)

# sanity check. did we lose any rows? nope
print(len(top_80), len(bottom_20), len(df))


# collapse bottom_20 into one row: 
# product | amount
# other   | 10000

total_amount = bottom_20['amount'].sum()
bottom_20 = {'product': 'other', 'amount': total_amount}

top_80 = top_80[['product', 'amount']]

temp_df = top_80.append(bottom_20, ignore_index = True)

temp_df
# Out:
# 225 875 1100
#         product  amount
# 0    teptlezwgy  170577
# 1    pweflqandk  147300
# 2    mkbtkziftf  106332
# 3    ptctwlpjbg   91496
# 4    mwvqtdpxik   84535
# ..          ...     ...
# 221  zamghxyvuz    3711
# 222  ldbbjdniot    3710
# 223  amwobstgaq    3704
# 224  rzjepepehw    3688
# 225       other  831224
#
# [226 rows x 2 columns]

# %%
temp_df['cumulative_sum'] = temp_df.amount.cumsum()
temp_df['cumulative_perc'] = 100*temp_df.cumulative_sum/temp_df.amount.sum()
temp_df.head()
# Out:
#       product  amount  cumulative_sum  cumulative_perc
# 0  teptlezwgy  170577          170577         4.111711
# 1  pweflqandk  147300          317877         7.662336
# 2  mkbtkziftf  106332          424209        10.225439
# 3  ptctwlpjbg   91496          515705        12.430925
# 4  mwvqtdpxik   84535          600240        14.468617

# %%
temp_df.to_csv('data/plotly_data.csv', index=True)
temp_df = pd.read_csv('data/plotly_data.csv', index_col=0)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

cat = 'product'
num = 'amount'
title = 'This is a Pareto chart in Plotly'

trace1 = go.Bar(
    x=temp_df[cat],
    y=temp_df[num],
    name=num,
    marker=dict(
        color='rgb(34,163,192)'
               )
)
trace2 = go.Scatter(
    x=temp_df[cat],
    y=temp_df['cumulative_perc'],
    name='Cumulative Percentage',
    yaxis='y2'

)

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(trace1)
fig.add_trace(trace2,secondary_y=True)
fig['layout'].update(height = 600, width = 800, title = title, xaxis=dict(
      tickangle=-90
    ))

# iplot(fig)

fig
# Out:
# <div>                            <div id="265c8b0a-8a4e-4b9f-aa05-dadc02c14e65" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("265c8b0a-8a4e-4b9f-aa05-dadc02c14e65")) {                    Plotly.newPlot(                        "265c8b0a-8a4e-4b9f-aa05-dadc02c14e65",                        [{"marker":{"color":"rgb(34,163,192)"},"name":"amount","x":["teptlezwgy","pweflqandk","mkbtkziftf","ptctwlpjbg","mwvqtdpxik","svtvxbgkme","hbyryhheza","tcuezvzqqi","pxjqehjbwb","hvfwbftoue","svporpowfu","ouxsqeoywg","eotwqmyteb","jpxsnpgkuq","favdwdrpkt","ghswgereke","hlhydxqdjb","pwvgdgcjdx","ndxqpalqoc","btwgucqzmh","dwlfefjolw","kexowezosu","sfqcnrscpt","odhkhpjfej","snzygvavsa","dwmyupnjny","mhfthvjuhg","vhdrltpkag","iizhtlsrjw","cajkayqvkh","lzgaeyviko","btrocbulee","pzhlwnpgke","noznkqraez","vwktbgrckb","yhgvudrebv","ebybuamcyc","knvzoppvnl","rpeupyxunk","ozoearxfgn","rsfduujnog","hlujhllcyo","bqfpvdvlvu","rfyncnxcqk","objuzvbkfj","slardqrtyr","piylonwmwy","zlwljwzmwp","cruxgxqour","xldbtbzjlf","vzaovonsun","xozsfsnzrp","rlcljcpdyk","qzyejnscwe","mtwngmcmgu","tqzrmuacxf","bknmbqygbs","tybsqsosjp","wrtlxtbwsn","uojrgaptqn","ktntarrtsv","lqbbvroxnl","whvlcygtke","fxixrqdsyx","lsxyrejbfb","sbhtrfhrpd","xqkanxrnwu","ziqxnxxaae","xmeyruisis","opizjfvvvx","fikjcjtrbw","cskfxihykm","dcbdyzztmb","xnhojxycce","bbhwapjhsj","mtqabhbnca","jzsdlequwg","dhytiozzwh","vgajgvqjci","vhglbhvgcx","onmyoguwam","yxmomlzvbi","ocuxmjqejs","uwkllsbsel","sedniilazs","bdupgzihij","kfpvszcksl","jjhnijejjw","ctdoekvbil","kratnsbgdz","ntqcczlngs","ikkhykfjab","xpbqtbsmwy","smfvweqdho","tibjnxnptz","xopdqhvyii","tcfsvlsiss","dqosmnsufv","yzgwflvuwv","jdcjgwktkf","qxspqijbue","qffaaccnbf","exuklqyunu","fqsembajbn","yjvijxfxny","kmqzadqbyu","vwhbymfmev","yvzrmfoeua","casiiamrei","yifxsdzxch","ryqyrjtjoe","wpxmplazau","hcfndpscef","itpdcxnjsq","ipperjuhwr","lygnepecna","byngjbvvbo","ymbajypwuv","ntdilhipye","ygrhvdpnms","dssauknkct","gdtaqaqwrz","lailxbsnkt","etxzzzebpu","ingvlwuhdj","ecfrphuzau","cpanuohnvl","ugoyyzgfcj","jkcgcoaerr","byljnvdypv","vashetlrrn","sdpaqspynf","prrixlnymt","ofgzxzncxd","kekmwwgusf","gtkhimmtkb","kyjhbsqddd","lzsgpgjadr","rducgizwfo","ciyotrjnjs","gijrniqyjh","rylioopfpb","edvxespycm","nkhlsjennd","ejjuifrcvl","shqyowyfeu","jqyojrdahq","kgrcfsleva","zxekuxajmr","jjcnkoeoqm","tbjuoddvkx","rziezncciy","llglufnaoz","icooynmawm","uwhwjurbdg","zyozarinym","ozhsfmrmcc","hmowwlqgcc","wkuzbssqxe","yxjihdqjnw","tqwajiivyn","lntevqsrll","ngdwoxtuhe","pxuhgutkaq","tbeblldndt","enqtoucfvj","tstkncukul","wreycgzjax","krslbvjpsj","zeqilgypba","nhmihuyxwt","xsjlhqanby","ilnkycxgrq","vdiuumxgcw","uvunxmnpwa","nminfbrpwy","fvjuuaucec","xyzbebtnlf","ravspkgwfy","dpdfvlxbut","ijgwmgdigt","jflqxqobgr","uscxkghqjs","vsibnlkewt","hjqbqfkwdf","xpwxyftvsb","goyaiboato","iwoacrvxol","imsthwglch","wdtiucsjda","czxokfhhuc","hwicdylyec","hcppwtemmk","miyjwmizvf","bhwdymjanx","svyeloswfa","oswtzbraym","satiorpbqm","ejektlxmsr","rzqmyhwzlv","coeriieurg","qporrpulib","ayjyhpsjtw","zcjmkicdvf","iwfnsjmfbe","eudkcvjlwn","unxycswmaa","pzlbupbgnm","uolzmrddbu","zeacxjwcft","evbbhhsvcx","skiydmissp","juqjzsmrwb","lmazgdgatc","ifkkjatqiv","skeogjvnkz","hymtktaigr","uqjxzwzvlu","sypypeipye","ooxucmydxv","rpjzpombfk","zamghxyvuz","ldbbjdniot","amwobstgaq","rzjepepehw","other"],"y":[170577,147300,106332,91496,84535,81432,70215,63645,60858,60624,59453,53080,49035,46050,43093,42060,41152,40230,38543,36549,35395,35016,32775,27762,27455,26785,25681,25654,25169,24996,24833,23213,22448,20920,19387,18972,18775,18282,18221,17847,17826,17690,17383,16551,16087,16015,15844,15371,15012,14902,14868,14726,14696,14614,14491,14438,14430,14240,14124,14117,14112,13895,13796,13609,13606,13173,13002,12509,12485,11914,11650,11601,11497,11432,11403,11030,10895,10837 ...

# %%
import dash
from dash import dcc
from dash import html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig)
])

app.run_server(debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
